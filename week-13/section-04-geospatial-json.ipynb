# %% [markdown]
# # Working with Geospatial Data
#
#
# In this lesson, you work with ```JSON``` data accessed via the Colorado information warehouse. The data will contain geospatial information nested within it that will allow us to create a map of the data.
#
#
# Check out the map [Colorado DWR Current Surface Water Conditions map](https://data.colorado.gov/Water/DWR-Current-Surface-Water-Conditions-Map-Statewide/j5pc-4t32).
#
# Remember from the previous lesson, APIs can be used for many different things. Web developers (people who program and create web sites and cool applications) can use APIs to create user friendly interfaces - like the map in the previous example that allows us to look at and interact with data. These APIs are similar to, if not the same as, the ones that you often use to access data in ```Python```.
#
# In this lesson, you will access the data used to create the map at the link above using ```Python```.
#
# - The data that you will use are located here: [View JSON format data used to create surface water map](https://data.colorado.gov/resource/j5pc-4t32.json).
# - And you can learn more about the data here: [View CO Current water surface](https://data.colorado.gov/Water/Current-Surface-Water-Conditions-in-Colorado/4yw9-a5y6).

# %%
import requests
import folium
import urllib
from pandas.io.json import json_normalize
import pandas as pd
import folium
from geopandas import GeoDataFrame
from shapely.geometry import Point
# Out:
# /Users/brpagan/anaconda3/envs/traillop/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/6f/styv5_3s4vz2g80lbzd67b8m0000gq/T/ipykernel_11012/3499686145.py:7: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   from geopandas import GeoDataFrame

# %%
water_base_url = "https://data.colorado.gov/resource/j5pc-4t32.json?"
water_full_url = water_base_url + "station_status=Active" + "&county=BOULDER"

# %%
water_full_url
# Out:
# 'https://data.colorado.gov/resource/j5pc-4t32.json?station_status=Active&county=BOULDER'

# %%
data = requests.get(water_full_url)

# %%
type(data.json())
# Out:
# list

# %% [markdown]
# Remember that the JSON structure supports hierarchical data and can be NESTED. If you look at the structure of the ```.json``` file below, you can see that the location object, is nested with three sub objects:
#
# - latitude
# - longitude
# - needs_recoding
#
# Since ```data.json()``` is a ```list``` you can print out just the first few items of the list to look at your data as a sanity check.

# %%
data.json()[:2]
# Out:
# [{'station_name': 'WELLMAN DITCH TAIL',
#   'div': '1',
#   'location': {'latitude': '40.007326',
#    'needs_recoding': False,
#    'longitude': '-105.216119'},
#   'dwr_abbrev': 'WLMTALCO',
#   'data_source': 'Co. Division of Water Resources',
#   'amount': '0.00',
#   'station_type': 'Diversion',
#   'wd': '6',
#   'http_linkage': {'url': 'https://dwr.state.co.us/Tools/Stations/WLMTALCO'},
#   'date_time': '2023-04-11T16:15:00.000',
#   'county': 'BOULDER',
#   'variable': 'DISCHRG',
#   'station_status': 'Active'},
#  {'station_name': 'NORTH BOULDER FARMERS DITCH RETURN TO BOULDER CREEK',
#   'div': '1',
#   'location': {'latitude': '40.01495',
#    'needs_recoding': False,
#    'longitude': '-105.278493'},
#   'dwr_abbrev': 'NBFRTNCO',
#   'data_source': 'Co. Division of Water Resources',
#   'amount': '0.00',
#   'station_type': 'Diversion',
#   'wd': '6',
#   'http_linkage': {'url': 'https://dwr.state.co.us/Tools/Stations/NBFRTNCO'},
#   'date_time': '2023-04-11T15:15:00.000',
#   'county': 'BOULDER',
#   'variable': 'DISCHRG',
#   'station_status': 'Active'}]

# %% [markdown]
# ## Convert JSON to Pandas DataFrame
# Now that you have pulled down the data from the website, you have it in the ```JSON``` format. For the next step, you will use the ```json_normalize()``` function from the Pandas library to convert this data into a ```Pandas``` ```DataFrame```.
#
# This function helps organize and flatten data into a semi-structed table. To learn more, check out the [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html)!

# %%
from pandas.io.json import json_normalize

# %%
result = json_normalize(data.json())
# Out:
# /var/folders/6f/styv5_3s4vz2g80lbzd67b8m0000gq/T/ipykernel_11012/3787952420.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   result = json_normalize(data.json())

# %%
result.head()
# Out:
#                                         station_name div dwr_abbrev  \
# 0                                 WELLMAN DITCH TAIL   1   WLMTALCO
# 1  NORTH BOULDER FARMERS DITCH RETURN TO BOULDER ...   1   NBFRTNCO
# 2                  LEFT HAND CREEK NEAR BOULDER, CO.   1   LEFCRECO
# 3                                        BONUS DITCH   1   BONDITCO
# 4                             WEBSTER MCCASLIN DITCH   1   WEBDITCO
#
#                                     data_source amount station_type wd  \
# 0               Co. Division of Water Resources   0.00    Diversion  6
# 1               Co. Division of Water Resources   0.00    Diversion  6
# 2               Co. Division of Water Resources   8.72       Stream  5
# 3  Cooperative Program of CDWR, NCWCD & SVLHWCD   0.14    Diversion  5
# 4  Cooperative Program of CDWR, NCWCD & SVLHWCD   0.26    Diversion  5
#
#                  date_time   county variable station_status location.latitude  \
# 0  2023-04-11T16:15:00.000  BOULDER  DISCHRG         Active         40.007326
# 1  2023-04-11T15:15:00.000  BOULDER  DISCHRG         Active          40.01495
# 2  2023-04-11T16:15:00.000  BOULDER  DISCHRG         Active         40.126407
# 3  2023-04-11T16:00:00.000  BOULDER  DISCHRG         Active         40.153369
# 4  2023-04-11T16:00:00.000  BOULDER  DISCHRG         Active         40.193287
#
#    location.needs_recoding location.longitude  \
# 0                    False        -105.216119
# 1                    False        -105.278493
# 2                    False         -105.30451
# 3                    False        -105.088705
# 4                    False        -105.210434
#
#                                   http_linkage.url usgs_station_id stage flag
# 0  https://dwr.state.co.us/Tools/Stations/WLMTALCO             NaN   NaN  NaN
# 1  https://dwr.state.co.us/Tools/Stations/NBFRTNCO             NaN   NaN  NaN
# 2  https://dwr.state.co.us/Tools/Stations/LEFCRECO        06724500  0.35  NaN
# 3  https://dwr.state.co.us/Tools/Stations/BONDITCO             NaN  0.05  NaN
# 4  https://dwr.state.co.us/Tools/Stations/WEBDITCO             NaN  0.13  NaN

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result.columns
# Out:
# Index(['station_name', 'div', 'dwr_abbrev', 'data_source', 'amount',
#        'station_type', 'wd', 'date_time', 'county', 'variable',
#        'station_status', 'location.latitude', 'location.needs_recoding',
#        'location.longitude', 'http_linkage.url', 'usgs_station_id', 'stage',
#        'flag'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning for Visualization
# Now you can clean up the data. Notice that your longitude and latitude values are stored as strings. Do you think can create a map if these values are stored as strings?

# %%
result['location.latitude'][0]
# Out:
# '40.007326'

# %% [markdown]
# You can convert the strings to type float as follows.

# %%
result['location.latitude'] = result['location.latitude'].astype(float)

# %%
result['location.latitude'][0]
# Out:
# 40.007326

# %%
result['location.longitude'] = result['location.longitude'].astype(float)

# %%
result['location.longitude'][0]
# Out:
# -105.216119

# %% [markdown]
# Now that you have numeric values for mapping, make sure that are are no missing values.

# %%
result.shape
# Out:
# (107, 18)

# %%
result['location.longitude'].isna().any()
# Out:
# False

# %%
result['location.latitude'].isna().any()
# Out:
# False

# %% [markdown]
# There are no ```nan``` values in this data. However, if there were, you could remove rows where a column has a nan value in a specific column with the following: ```result_nonan = result.dropna(subset=['location.longitude', 'location.latitude'])```

# %% [markdown]
# ## Data Visualization
# You will use the folium package to visualize the data. One approach you could take would be to convert your Pandas DataFrame to a Geopandas DataFrame for easy mapping.

# %%
geometry = [Point(xy) for xy in zip(result['location.longitude'], result['location.latitude'])]
crs = {'init': 'epsg:4326'}
gdf = GeoDataFrame(result, crs=crs, geometry=geometry)
gdf.head()
# Out:
# /Users/brpagan/anaconda3/envs/traillop/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#                                         station_name div dwr_abbrev  \
# 0                                 WELLMAN DITCH TAIL   1   WLMTALCO
# 1  NORTH BOULDER FARMERS DITCH RETURN TO BOULDER ...   1   NBFRTNCO
# 2                  LEFT HAND CREEK NEAR BOULDER, CO.   1   LEFCRECO
# 3                                        BONUS DITCH   1   BONDITCO
# 4                             WEBSTER MCCASLIN DITCH   1   WEBDITCO
#
#                                     data_source amount station_type wd  \
# 0               Co. Division of Water Resources   0.00    Diversion  6
# 1               Co. Division of Water Resources   0.00    Diversion  6
# 2               Co. Division of Water Resources   8.72       Stream  5
# 3  Cooperative Program of CDWR, NCWCD & SVLHWCD   0.14    Diversion  5
# 4  Cooperative Program of CDWR, NCWCD & SVLHWCD   0.26    Diversion  5
#
#                  date_time   county variable station_status  \
# 0  2023-04-11T16:15:00.000  BOULDER  DISCHRG         Active
# 1  2023-04-11T15:15:00.000  BOULDER  DISCHRG         Active
# 2  2023-04-11T16:15:00.000  BOULDER  DISCHRG         Active
# 3  2023-04-11T16:00:00.000  BOULDER  DISCHRG         Active
# 4  2023-04-11T16:00:00.000  BOULDER  DISCHRG         Active
#
#    location.latitude  location.needs_recoding  location.longitude  \
# 0          40.007326                    False         -105.216119
# 1          40.014950                    False         -105.278493
# 2          40.126407                    False         -105.304510
# 3          40.153369                    False         -105.088705
# 4          40.193287                    False         -105.210434
#
#                                   http_linkage.url usgs_station_id stage flag  \
# 0  https://dwr.state.co.us/Tools/Stations/WLMTALCO             NaN   NaN  NaN
# 1  https://dwr.state.co.us/Tools/Stations/NBFRTNCO             NaN   NaN  NaN
# 2  https://dwr.state.co.us/Tools/Stations/LEFCRECO        06724500  0.35  NaN
# 3  https://dwr.state.co.us/Tools/Stations/BONDITCO             NaN  0.05  NaN
# 4  https://dwr.state.co.us/Tools/Stations/WEBDITCO             NaN  0.13  NaN
#
#                       geometry
# 0  POINT (-105.21612 40.00733)
# 1  POINT (-105.27849 40.01495)
# 2  POINT (-105.30451 40.12641)
# 3  POINT (-105.08871 40.15337)
# 4  POINT (-105.21043 40.19329)

# %% [markdown]
# Then, you can plot the data using the folium functions ```GeoJson()``` and ```add_to()``` to add the data from the ```Geopandas``` ```DataFrame``` to the map object

# %%
m = folium.Map([40.01, -105.27], zoom_start= 10, tiles='cartodbpositron')
folium.GeoJson(gdf).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fde14b17ef81a491bb002a8be1a7d0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fde14b17ef81a491bb002a8be1a7d0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fde14b17ef81a491bb002a8be1a7d0f = L.map(
#                 &quot;map_1fde14b17ef81a491bb002a8be1a7d0f&quot;,
#                 {
#                     center: [40.01, -105.27],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2a978ac1ae64bc63fa3c9e59680fb3f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fde14b17ef81a491bb002a8be1a7d0f);
#
#
#
#         function geo_json_b32259d12b4f3a7e89a109f0f72b4a0e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b32259d12b4f3a7e89a109f0f72b4a0e = L.geoJson(null, {
#                 onEachFeature: geo_json_b32259d12b4f3a7e89a109f0f72b4a0e_onEachFeature,
#
#         });
#
#         function geo_json_b32259d12b4f3a7e89a109f0f72b4a0e_add (data) {
#             geo_json_b32259d12b4f3a7e89a109f0f72b4a0e
#                 .addData(data)
#                 .addTo(map_1fde14b17ef81a491bb002a8be1a7d0f);
#         }
#             geo_json_b32259d12b4f3a7e89a109f0f72b4a0e_add({&quot;bbox&quot;: [-105.517111, 39.914612, -105.072502, 40.260833], &quot;features&quot;: [{&quot;bbox&quot;: [-105.216119, 40.007326, -105.216119, 40.007326], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.216119, 40.007326], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amount&quot;: &quot;0.00&quot;, &quot;county&quot;: &quot;BOULDER&quot;, &quot;data_source&quot;: &quot;Co. Division of Water Resources&quot;, &quot;date_time&quot;: &quot;2023-04-11T16:15:00.000&quot;, &quot;div&quot;: &quot;1&quot;, &quot;dwr_abbrev&quot;: &quot;WLMTALCO&quot;, &quot;flag&quot;: null, &quot;http_linkage.url&quot;: &quot;https://dwr.state.co.us/Tools/Stations/WLMTALCO&quot;, &quot;location.latitude&quot;: 40.007326, &quot;location.longitude&quot;: -105.216119, &quot;location.needs_recoding&quot;: false, &quot;stage&quot;: null, &quot;station_name&quot;: &quot;WELLMAN DITCH TAIL&quot;, &quot;station_status&quot;: &quot;Active&quot;, &quot;station_type&quot;: &quot;Diversion&quot;, &quot;usgs_station_id&quot;: null, &quot;variable&quot;: &quot;DISCHRG&quot;, &quot;wd&quot;: &quot;6&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.278493, 40.01495, -105.278493, 40.01495], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.278493, 40.01495], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amount&quot;: &quot;0.00&quot;, &quot;county&quot;: &quot;BOULDER&quot;, &quot;data_source&quot;: &quot;Co. Division of Water Resources&quot;, &quot;date_time&quot;: &quot;2023-04-11T15:15:00.000&quot;, &quot;div&quot;: &quot;1&quot;, &quot;dwr_abbrev&quot;: &quot;NBFRTNCO&quot;, &quot;flag&quot;: null, &quot;http_linkage.url&quot;: &quot;https://dwr.state.co.us/Tools/Stations/NBFRTNCO&quot;, &quot;location.latitude&quot;: 40.01495, &quot;location.longitude&quot;: -105.278493, &quot;location.needs_recoding&quot;: false, &quot;stage&quot;: null, &quot;station_name&quot;: &quot;NORTH BOULDER FARMERS DITCH RETURN TO BOULDER CREEK&quot;, &quot;station_status&quot;: &quot;Active&quot;, &quot;station_type&quot;: &quot;Diversion&quot;, &quot;usgs_station_id&quot;: null, &quot;variable&quot;: &quot;DISCHRG&quot;, &quot;wd&quot;: &quot;6&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.30451, 40.126407, -105.30451, 40.126407], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.30451, 40.126407], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amount&quot;: &quot;8.72&quot;, &quot;county&quot;: &quot;BOULDER&quot;, &quot;data_source&quot;: &quot;Co. Division of Water Resources&quot;, &quot;date_time&quot;: &quot;2023-04-11T16:15:00.000&quot;, &quot;div&quot;: &quot;1&quot;, &quot;dwr_abbrev&quot;: &quot;LEFCRECO&quot;, &quot;flag&quot;: null, &quot;http_linkage.url&quot;: &quot;https://dwr.state.co.us/Tools/Stations/LEFCRECO&quot;, &quot;location.latitude&quot;: 40.126407, &quot;location.longitude&quot;: -105.30451, &quot;location.needs_recoding&quot;: false, &quot;stage&quot;: &quot;0.35&quot;, &quot;station_name&quot;: &quot;LEFT HAND CREEK NEAR BOULDER, CO.&quot;, &quot;station_status&quot;: &quot;Active&quot;, &quot;station_type&quot;: &quot;Stream&quot;, &quot;usgs_station_id&quot;: &quot;06724500&quot;, &quot;variable&quot;: &quot;DISCHRG&quot;, &quot;wd&quot;: &quot;5&quot;}, &quot;type&quot;: &quot;Feature&

# %% [markdown]
# Great! You now have an interactive map in your notebook!
#
# You can also cluster the markers, and add a popup to each marker, so you can give your viewers more information about station: such as its name and the amount of precipitation measured.
#
# For this example below, you will work with the ```Pandas``` ```DataFrame``` you originally created from the ```JSON```, instead of the ```Geopandas GeoDataFrame```.

# %%
# Get the latitude and longitude from result as a list
locations = result[['location.latitude', 'location.longitude']]
coords = locations.values.tolist()

# %%
from folium.plugins import MarkerCluster

m = folium.Map([40.01, -105.27], zoom_start= 10, tiles='cartodbpositron')

marker_cluster = MarkerCluster().add_to(m)

for point in range(0, len(coords)):
    folium.Marker(location = coords[point], popup= 'Name: ' + result['station_name'][point] + ' ' + 'Precip: ' + str(result['amount'][point])).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_250052b61aee317254f9eef30e9faf64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_250052b61aee317254f9eef30e9faf64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_250052b61aee317254f9eef30e9faf64 = L.map(
#                 &quot;map_250052b61aee317254f9eef30e9faf64&quot;,
#                 {
#                     center: [40.01, -105.27],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcc18b5066da9042f666908b82a231c6 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_250052b61aee317254f9eef30e9faf64);
#
#
#             var marker_cluster_e36a037ac049e7aa4b08c7252632cba8 = L.markerClusterGroup(
#                 {}
#             );
#             map_250052b61aee317254f9eef30e9faf64.addLayer(marker_cluster_e36a037ac049e7aa4b08c7252632cba8);
#
#
#             var marker_f9ca2357ee2f2fb6b074b7c9298be22a = L.marker(
#                 [40.007326, -105.216119],
#                 {}
#             ).addTo(marker_cluster_e36a037ac049e7aa4b08c7252632cba8);
#
#
#         var popup_7ff2564021c3a3ea137a11abd04749d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81b0ae20259dd7617ec9f387e3bd1b6a = $(`&lt;div id=&quot;html_81b0ae20259dd7617ec9f387e3bd1b6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: WELLMAN DITCH TAIL Precip: 0.00&lt;/div&gt;`)[0];
#                 popup_7ff2564021c3a3ea137a11abd04749d3.setContent(html_81b0ae20259dd7617ec9f387e3bd1b6a);
#
#
#
#         marker_f9ca2357ee2f2fb6b074b7c9298be22a.bindPopup(popup_7ff2564021c3a3ea137a11abd04749d3)
#         ;
#
#
#
#
#             var marker_cfc9f37877f8611beb86d95c358ab471 = L.marker(
#                 [40.01495, -105.278493],
#                 {}
#             ).addTo(marker_cluster_e36a037ac049e7aa4b08c7252632cba8);
#
#
#         var popup_4cce28dcc5e0e7e9ea787d36c2ae5690 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3aa6c1b04e99f5c7078fc904440eccd = $(`&lt;div id=&quot;html_d3aa6c1b04e99f5c7078fc904440eccd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: NORTH BOULDER FARMERS DITCH RETURN TO BOULDER CREEK Precip: 0.00&lt;/div&gt;`)[0];
#                 popup_4cce28dcc5e0e7e9ea787d36c2ae5690.setContent(html_d3aa6c1b04e99f5c7078fc904440eccd);
#
#
#
#         marker_cfc9f37877f8611beb86d95c358ab471.bindPopup(popup_4cce28dcc5e0e7e9ea787d36c2ae5690)
#         ;
#
#
#
#
#             var marker_67439cf72828e35b18ce0abbe6904bf8 = L.marker(
#                 [40.126407, -105.30451],
#                 {}
#             ).addTo(marker_cluster_e36a037ac049e7aa4b08c7252632cba8);
#
#
#         var popup_ef1efedfe4a8a795c9b54af925848d5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c68e39d54ed9668edacf62861ba00278 = $(`&lt;div id=&quot;html_c68e39d54ed9668edacf62861ba00278&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: LEFT HAND CREEK NEAR BOULDER, CO. Precip: 8.72&lt;/div&gt;`)[0];
#                 popup_ef1efedfe4a8a795c9b54af925848d5a.setContent(html_c68e39d54ed9668edacf62861ba00278);
#
#
#
#         marker_67439cf72828e35b18ce0abbe6904bf8.bindPopup(popup_ef1efedfe4a8a795c9b54af925848d5a)
#         ;
#
#
#
#
#             var marker_a99831d8149269335ab649594f1b0994 = L.marker(
#                 [40.153369, -105.088705],
#                 {}
#             ).addTo(marker_cluster_e36a037ac049e7aa4b08c7252632cba8);
#
#
#         var popup_6fb33d2cde0c4c0c889dce118512fa8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5dea7253f41ae527b73cbc1e62ab4a83 = $(`&lt;div id=&quot;html_5dea7253f41ae527b73cbc1e62ab4a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: BONUS DITCH Precip: 0.14&lt;/div&gt;`)[0];
#                 popup_6fb33d2cde0c4c0c889dce118512fa8e.setContent(html_5dea7253f41ae527b73cbc1e62ab4a83);
#
#
#
#         marker_a99831d8149269335ab649594f1b0994.bindPopup(popup_6fb33d2cde0c4c0c889dce118512fa8e)
#         ;
#
#
#
#
#             var marker_
