# %% [markdown]
# ## Jordan Taylor
# ## Sandbox - 4/25/23

# %% [markdown]
# ## - For my Geospatial project I'll be looking at the correlation between average income by zipcode compared to the prevalence of grocery stores. And liquor or corner stores as well.
# ## - My inspiration for the project was simple - whenever I drive from West LA to downtown and take either Olympic Blvd or Wilshire Blvd, I notice there's less and less grocery stores and liquor stores are more common.
# ## - I've found an interesting .geojson file that has social sensitivity data for all of Los Angeles County, containing numerous parameters. I'll utilize some of them in my final project.

# %%
import pandas as pd
import geopandas as gpd

fp = "LA_county_social_index.geojson"
data = gpd.read_file(fp)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/tljh/user/share/proj failed

# %%
data.head(10)
# Out:
#            Census_Tract              County CSA_Type              CSA_Label  \
# 0  Census Tract 5709.02  Los Angeles County     City       City of Lakewood
# 1  Census Tract 5715.02  Los Angeles County     City     City of Long Beach
# 2  Census Tract 9106.05  Los Angeles County     City       City of Palmdale
# 3  Census Tract 9107.12  Los Angeles County     City       City of Palmdale
# 4  Census Tract 9107.15  Los Angeles County     City       City of Palmdale
# 5  Census Tract 9200.23  Los Angeles County     City  City of Santa Clarita
# 6  Census Tract 9200.37  Los Angeles County     City  City of Santa Clarita
# 7  Census Tract 9200.45  Los Angeles County     City  City of Santa Clarita
# 8  Census Tract 9201.10  Los Angeles County     City  City of Santa Clarita
# 9  Census Tract 9203.14  Los Angeles County     City  City of Santa Clarita
#
#                     DRP_Planning_Area DPH_Service_Planning_Area  \
# 0               Gateway Planning Area                      East
# ...

# %% [markdown]
# ## Looking into the .geojson file further:

# %%
# https://data.lacounty.gov/datasets/709afd7548f6491eb74c2928e6ce06df_0/explore?location=34.015922%2C-118.258322%2C10.00

# %% [markdown]
# ### Relevant social indicators:
# - Race
# - Median Income ($)
# - Renters
# - No Health Insurance
# - Poverty
# - Limited English
# - Children, Older Adults, etc (%)
# - Cardiovascular Disease
# - Disability
# - Households Without Vehicle Access
# - Social Vulnerabilty Index (SVI)
